# %%
import pandas as pd
df = pd.read_csv("groww_banking_&_financial_services_fund.csv")
df
# Out:
#                                 Constituent Ticker Symbol  Holding Weight (%)  \
# 0                            ICICI Bank Ltd     ICICIBANK               20.57
# 1                             HDFC Bank Ltd      HDFCBANK               19.89
# 2                       State Bank of India          SBIN                8.97
# 3            SBI Life Insurance Company Ltd       SBILIFE                5.06
# 4                         Bajaj Finance Ltd    BAJFINANCE                4.91
# 5                             Axis Bank Ltd      AXISBANK                3.76
# 6                MAS Financial Services Ltd        MASFIN                3.44
# 7                         Indusind Bank Ltd    INDUSINDBK                2.96
# 8         HDFC Asset Management Company Ltd       HDFCAMC                2.78
# 9                  CreditAccess Grameen Ltd     CREDITACC                2.36
# 10                             CSB Bank Ltd       CSBBANK                2.32
# ...

# %%
df.columns = df.columns.str.strip()

# %%
hdfc_amc_index = df[df['Constituent'] == 'HDFC Asset Management Company Ltd'].index[0]

# %%
hdfc_amc_index
# Out:
# 8

# %%
df.loc[8, "2025 High Forecast (₹) + % Change"] = "₹4,010.00 +5.01%"
df.loc[8, "2025 Median Forecast (₹) + % Change"] = "₹3,470.00 -9.13%"
df.loc[8, "2025 Low Forecast (₹) + % Change"] = "₹2,050.00 -46.32%"

# %%
df
# Out:
#                                 Constituent Ticker Symbol  Holding Weight (%)  \
# 0                            ICICI Bank Ltd     ICICIBANK               20.57
# 1                             HDFC Bank Ltd      HDFCBANK               19.89
# 2                       State Bank of India          SBIN                8.97
# 3            SBI Life Insurance Company Ltd       SBILIFE                5.06
# 4                         Bajaj Finance Ltd    BAJFINANCE                4.91
# 5                             Axis Bank Ltd      AXISBANK                3.76
# 6                MAS Financial Services Ltd        MASFIN                3.44
# 7                         Indusind Bank Ltd    INDUSINDBK                2.96
# 8         HDFC Asset Management Company Ltd       HDFCAMC                2.78
# 9                  CreditAccess Grameen Ltd     CREDITACC                2.36
# 10                             CSB Bank Ltd       CSBBANK                2.32
# ...

# %%
# Fill in the values for Can Fin Homes Ltd
df.loc[14, "2025 High Forecast (₹) + % Change"] = "₹1,000.00 +38.04%"
df.loc[14, "2025 Median Forecast (₹) + % Change"] = "₹900.00 +24.23%"
df.loc[14, "2025 Low Forecast (₹) + % Change"] = "₹607.00 -16.21%"

# %%
df
# Out:
#                                 Constituent Ticker Symbol  Holding Weight (%)  \
# 0                            ICICI Bank Ltd     ICICIBANK               20.57
# 1                             HDFC Bank Ltd      HDFCBANK               19.89
# 2                       State Bank of India          SBIN                8.97
# 3            SBI Life Insurance Company Ltd       SBILIFE                5.06
# 4                         Bajaj Finance Ltd    BAJFINANCE                4.91
# 5                             Axis Bank Ltd      AXISBANK                3.76
# 6                MAS Financial Services Ltd        MASFIN                3.44
# 7                         Indusind Bank Ltd    INDUSINDBK                2.96
# 8         HDFC Asset Management Company Ltd       HDFCAMC                2.78
# 9                  CreditAccess Grameen Ltd     CREDITACC                2.36
# 10                             CSB Bank Ltd       CSBBANK                2.32
# ...

# %%
df.loc[17, "2025 High Forecast (₹) + % Change"] = "₹800.60 +29.36%"
df.loc[17, "2025 Median Forecast (₹) + % Change"] = "₹797.50 +28.86%"
df.loc[17, "2025 Low Forecast (₹) + % Change"] = "₹784.90 +26.83%"

# %%
df
# Out:
#                                 Constituent Ticker Symbol  Holding Weight (%)  \
# 0                            ICICI Bank Ltd     ICICIBANK               20.57
# 1                             HDFC Bank Ltd      HDFCBANK               19.89
# 2                       State Bank of India          SBIN                8.97
# 3            SBI Life Insurance Company Ltd       SBILIFE                5.06
# 4                         Bajaj Finance Ltd    BAJFINANCE                4.91
# 5                             Axis Bank Ltd      AXISBANK                3.76
# 6                MAS Financial Services Ltd        MASFIN                3.44
# 7                         Indusind Bank Ltd    INDUSINDBK                2.96
# 8         HDFC Asset Management Company Ltd       HDFCAMC                2.78
# 9                  CreditAccess Grameen Ltd     CREDITACC                2.36
# 10                             CSB Bank Ltd       CSBBANK                2.32
# ...

# %%
df.to_csv("groww_banking_&_financial_services_fund.csv")
